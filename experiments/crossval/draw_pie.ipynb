# %%
import pandas as pd

# %%
df = pd.read_csv('train_df_folds.csv')

# %%
x_0 = df[df.fold == 0]

# %%
x_0[x_0['MGMT_value']==1]
# Out:
#      BraTS21ID  MGMT_value  fold
# 5            8           1     0
# 8           12           1     0
# 17          25           1     0
# 30          48           1     0
# 36          58           1     0
# ..         ...         ...   ...
# 525        775           1     0
# 534        789           1     0
# 550        807           1     0
# 551        808           1     0
# 560        823           1     0
#
# [62 rows x 3 columns]

# %%
x_1 = df[df.fold == 1]

# %%
x_1[x_1['MGMT_value']==1]
# Out:
#      BraTS21ID  MGMT_value  fold
# 1            2           1     1
# 4            6           1     1
# 23          33           1     1
# 26          43           1     1
# 43          66           1     1
# ..         ...         ...   ...
# 537        793           1     1
# 556        816           1     1
# 570        998           1     1
# 578       1007           1     1
# 579       1008           1     1
#
# [61 rows x 3 columns]

# %%
x_2 = df[df.fold == 2]

# %%
x_2[x_2['MGMT_value']==1]
# Out:
#      BraTS21ID  MGMT_value  fold
# 0            0           1     2
# 19          28           1     2
# 32          52           1     2
# 38          60           1     2
# 45          70           1     2
# ..         ...         ...   ...
# 523        773           1     2
# 538        794           1     2
# 539        795           1     2
# 575       1003           1     2
# 577       1005           1     2
#
# [61 rows x 3 columns]

# %%
x_3 = df[df.fold == 3]

# %%
x_3[x_3['MGMT_value']==1]
# Out:
#      BraTS21ID  MGMT_value  fold
# 7           11           1     3
# 13          20           1     3
# 24          35           1     3
# 35          56           1     3
# 40          62           1     3
# ..         ...         ...   ...
# 544        801           1     3
# 558        819           1     3
# 569        840           1     3
# 572       1000           1     3
# 574       1002           1     3
#
# [61 rows x 3 columns]

# %%
x_4 = df[df.fold == 4]

# %%
x_4[x_4['MGMT_value']==1]
# Out:
#      BraTS21ID  MGMT_value  fold
# 3            5           1     4
# 9           14           1     4
# 18          26           1     4
# 21          31           1     4
# 29          46           1     4
# ..         ...         ...   ...
# 554        811           1     4
# 562        828           1     4
# 567        838           1     4
# 571        999           1     4
# 573       1001           1     4
#
# [61 rows x 3 columns]

# %%
116-61
# Out:
# 55

# %%
df
# Out:
#      BraTS21ID  MGMT_value  fold
# 0            0           1     2
# 1            2           1     1
# 2            3           0     1
# 3            5           1     4
# 4            6           1     1
# ..         ...         ...   ...
# 577       1005           1     2
# 578       1007           1     1
# 579       1008           1     1
# 580       1009           0     3
# 581       1010           0     0
#
# [582 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 8))
ax = sns.countplot(data=df, y="MGMT_value")
ax.set_title("Distribution of Labels");
plt.savefig('res.png')

# %%
plt.figure(figsize=(6, 6))
df['MGMT_value'].value_counts(normalize=False).plot(y='MGMT_value', kind='pie', autopct='%1.1f%%')
plt.savefig('pie.png', bbox_inches='tight', pad_inches=0)

# %%
df['MGMT_value'].value_counts(normalize=False)
# Out:
# 1    306
# 0    276
# Name: MGMT_value, dtype: int64
